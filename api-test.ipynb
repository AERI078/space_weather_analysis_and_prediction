# %%
import requests
import json

# %%
# cme_url = f"https://api.nasa.gov/DONKI/CME?startDate=2025-08-11&endDate=2025-08-13&api_key={key}"

# %%
# fetch json content
# response = requests.get(cme_url)
# response.raise_for_status()

# data = response.json()

# %%
# print(data)

# %%
import pandas as pd
data = [{'activityID': '2025-08-10T02:12:00-CME-001', 'catalog': 'M2M_CATALOG', 'startTime': '2025-08-10T02:12Z', 'instruments': [{'displayName': 'SOHO: LASCO/C2'}, {'displayName': 'SOHO: LASCO/C3'}, {'displayName': 'STEREO A: SECCHI/COR2'}], 'sourceLocation': '', 'activeRegionNum': None, 'note': "Very minor CME seen to the west in SOHO LASCO C2 and in STEREO A COR2, becoming more narrow with time especially in SOHO LASCO C2 as the southeastern edge which made up the CME's main width fades away and becomes diffuse with time, most likely associated with far-sided eruptive activity. Not clearly seen in GOES CCOR-1.", 'submissionTime': '2025-08-11T13:02Z', 'versionId': 2, 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/40500/-1', 'cmeAnalyses': [{'isMostAccurate': True, 'time21_5': '2025-08-10T15:10Z', 'latitude': -18.0, 'longitude': 95.0, 'halfAngle': 26.0, 'speed': 274.0, 'type': 'S', 'featureCode': 'LE', 'imageType': 'running difference', 'measurementTechnique': 'SWPC_CAT', 'note': 'Leading edge measurement out to 7 solar radii before the CME fades away abruptly, especially in SOHO LASCO.', 'levelOfData': 0, 'tilt': None, 'minorHalfWidth': None, 'speedMeasuredAtHeight': 7.0, 'submissionTime': '2025-08-10T14:29Z', 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/40501/-1', 'enlilList': [{'modelCompletionTime': '2025-08-10T14:14Z', 'au': 2.0, 'estimatedShockArrivalTime': None, 'estimatedDuration': None, 'rmin_re': None, 'kp_18': None, 'kp_90': None, 'kp_135': None, 'kp_180': None, 'isEarthGB': False, 'isEarthMinorImpact': False, 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/40502/-1', 'impactList': [{'isGlancingBlow': True, 'isMinorImpact': False, 'location': 'Juice', 'arrivalTime': '2025-08-13T12:00Z'}], 'cmeIDs': ['2025-08-10T02:12:00-CME-001']}]}], 'linkedEvents': None, 'sentNotifications': None}, {'activityID': '2025-08-10T04:12:00-CME-001', 'catalog': 'M2M_CATALOG', 'startTime': '2025-08-10T04:12Z', 'instruments': [{'displayName': 'SOHO: LASCO/C2'}, {'displayName': 'SOHO: LASCO/C3'}, {'displayName': 'STEREO A: SECCHI/COR2'}], 'sourceLocation': 'N09E08', 'activeRegionNum': 14172, 'note': 'CME seen to the east in SOHO LASCO C2 and as well to the east in STEREO A COR2, though more narrow. Not seen in GOES CCOR-1. Possibly associated with an eruption near Active Region 4172 (N09E08) with significant deflection to the east as seen by a release of plasma in SDO AIA/GOES SUVI 304 around 2025-08-10T03:00Z near the active region. The CME does not fit a far-sided well after triangulation of the leading edge was performed, suggesting with relatively low confidence that the CME originates from the front-side.', 'submissionTime': '2025-08-11T13:03Z', 'versionId': 2, 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/40503/-1', 'cmeAnalyses': [{'isMostAccurate': True, 'time21_5': '2025-08-10T13:56Z', 'latitude': 6.0, 'longitude': -39.0, 'halfAngle': 14.0, 'speed': 330.0, 'type': 'S', 'featureCode': 'LE', 'imageType': 'running difference', 'measurementTechnique': 'SWPC_CAT', 'note': 'Triangulation of the leading edge using SOHO LASCO C2 and STEREO A COR2. Not seen well in SOHO LASCO C3.', 'levelOfData': 0, 'tilt': None, 'minorHalfWidth': None, 'speedMeasuredAtHeight': 10.0, 'submissionTime': '2025-08-10T14:58Z', 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/40504/-1', 'enlilList': [{'modelCompletionTime': '2025-08-10T15:00Z', 'au': 2.0, 'estimatedShockArrivalTime': None, 'estimatedDuration': None, 'rmin_re': None, 'kp_18': None, 'kp_90': None, 'kp_135': None, 'kp_180': None, 'isEarthGB': False, 'isEarthMinorImpact': False, 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/40505/-1', 'impactList': None, 'cmeIDs': ['2025-08-10T04:12:00-CME-001']}]}], 'linkedEvents': None, 'sentNotifications': None}, {'activityID': '2025-08-10T15:24:00-CME-001', 'catalog': 'M2M_CATALOG', 'startTime': '2025-08-10T15:24Z', 'instruments': [{'displayName': 'SOHO: LASCO/C2'}, {'displayName': 'SOHO: LASCO/C3'}, {'displayName': 'STEREO A: SECCHI/COR2'}, {'displayName': 'GOES: CCOR-1'}], 'sourceLocation': 'N05W75', 'activeRegionNum': 14168, 'note': 'Asymmetric CME associated with the long-duration M2.2-class flare and associated eruption from near Active Region 14168 (N05W75). The CME mainly appears to the west-northwest in SOHO LASCO C2/C3 and GOES CCOR-1 and to the southwest in STEREO A COR2 with no clear shock/bulk separation. The eruption is characterized by a brightening in SDO AIA 131 and quickly moving field lines seen best in SDO AIA 171 around 2025-08-10T15:00Z.', 'submissionTime': '2025-08-11T15:28Z', 'versionId': 2, 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/40511/-1', 'cmeAnalyses': [{'isMostAccurate': True, 'time21_5': '2025-08-10T20:08Z', 'latitude': 11.0, 'longitude': 76.0, 'halfAngle': 38.0, 'speed': 741.0, 'type': 'C', 'featureCode': 'LE', 'imageType': 'running difference', 'measurementTechnique': 'SWPC_CAT', 'note': 'Measurement of the bulk trying to incorporate as much of the CME as possible in SOHO LASCO and STEREO A, not incorporating some materials which escapes/accelerates out ahead of the leading edge, especially along the sides.', 'levelOfData': 0, 'tilt': None, 'minorHalfWidth': None, 'speedMeasuredAtHeight': 12.0, 'submissionTime': '2025-08-10T18:48Z', 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/40512/-1', 'enlilList': [{'modelCompletionTime': '2025-08-10T18:45Z', 'au': 2.0, 'estimatedShockArrivalTime': None, 'estimatedDuration': None, 'rmin_re': None, 'kp_18': None, 'kp_90': None, 'kp_135': None, 'kp_180': None, 'isEarthGB': False, 'isEarthMinorImpact': False, 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/40513/-1', 'impactList': [{'isGlancingBlow': False, 'isMinorImpact': False, 'location': 'BepiColombo', 'arrivalTime': '2025-08-11T11:19Z'}, {'isGlancingBlow': False, 'isMinorImpact': False, 'location': 'Juice', 'arrivalTime': '2025-08-12T11:23Z'}, {'isGlancingBlow': False, 'isMinorImpact': False, 'location': 'STEREO A', 'arrivalTime': '2025-08-12T19:39Z'}], 'cmeIDs': ['2025-08-10T15:24:00-CME-001']}, {'modelCompletionTime': '2025-08-10T19:30Z', 'au': 5.5, 'estimatedShockArrivalTime': None, 'estimatedDuration': None, 'rmin_re': None, 'kp_18': None, 'kp_90': None, 'kp_135': None, 'kp_180': None, 'isEarthGB': False, 'isEarthMinorImpact': False, 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/40516/-1', 'impactList': [{'isGlancingBlow': False, 'isMinorImpact': False, 'location': 'BepiColombo', 'arrivalTime': '2025-08-11T11:20Z'}, {'isGlancingBlow': False, 'isMinorImpact': False, 'location': 'Juice', 'arrivalTime': '2025-08-12T11:07Z'}, {'isGlancingBlow': False, 'isMinorImpact': False, 'location': 'STEREO A', 'arrivalTime': '2025-08-12T20:08Z'}, {'isGlancingBlow': True, 'isMinorImpact': False, 'location': 'Juno', 'arrivalTime': '2025-08-28T00:00Z'}], 'cmeIDs': ['2025-08-10T15:24:00-CME-001']}]}], 'linkedEvents': [{'activityID': '2025-08-10T14:57:00-FLR-001'}, {'activityID': '2025-08-12T16:00:00-IPS-001'}], 'sentNotifications': [{'messageID': '20250810-AL-004', 'messageIssueTime': '2025-08-10T18:58Z', 'messageURL': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/Alert/40514/1'}, {'messageID': '20250810-AL-005', 'messageIssueTime': '2025-08-10T19:50Z', 'messageURL': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/Alert/40517/1'}]}, {'activityID': '2025-08-10T19:36:00-CME-001', 'catalog': 'M2M_CATALOG', 'startTime': '2025-08-10T19:36Z', 'instruments': [{'displayName': 'SOHO: LASCO/C2'}, {'displayName': 'SOHO: LASCO/C3'}, {'displayName': 'STEREO A: SECCHI/COR2'}, {'displayName': 'GOES: CCOR-1'}], 'sourceLocation': '', 'activeRegionNum': None, 'note': 'Narrow faint jet-like CME seen to the west in all 3 coronagraphs (SOHO LASCO, STEREO A COR2 and GOES CCOR-1) - possibly an outflow from the M2.2-class flare-associated 2025-08-10T15:24Z CME. The front is fuzzy in all coronagraphs, but especially elusive in C3. No clear source was found for this event.', 'submissionTime': '2025-08-11T15:29Z', 'versionId': 2, 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/40519/-1', 'cmeAnalyses': [{'isMostAccurate': True, 'time21_5': '2025-08-11T03:12Z', 'latitude': -12.0, 'longitude': 95.0, 'halfAngle': 10.0, 'speed': 474.0, 'type': 'S', 'featureCode': 'LE', 'imageType': 'running difference', 'measurementTechnique': 'SWPC_CAT', 'note': 'A very approximate analysis based on the imperfect fit with two coronagraphs, SOHO LASCO C2/C3 and STEREO A COR2.', 'levelOfData': 0, 'tilt': None, 'minorHalfWidth': None, 'speedMeasuredAtHeight': None, 'submissionTime': '2025-08-11T02:51Z', 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/40520/-1', 'enlilList': []}], 'linkedEvents': None, 'sentNotifications': None}, {'activityID': '2025-08-10T23:48:00-CME-001', 'catalog': 'M2M_CATALOG', 'startTime': '2025-08-10T23:48Z', 'instruments': [{'displayName': 'SOHO: LASCO/C2'}, {'displayName': 'SOHO: LASCO/C3'}, {'displayName': 'STEREO A: SECCHI/COR2'}, {'displayName': 'GOES: CCOR-1'}], 'sourceLocation': '', 'activeRegionNum': None, 'note': 'Fast bright CME to the SSW in all coronagraphs (SOHO LASCO, STEREO A COR2 and GOES CCOR-1). Its source is a filament eruption from behind the SW limb seen in SDO AIA 131 and 304 after 2025-08-10T23Z. There is also an opening of field lines behind the SW limb seen in GOES SUVI 284 after 2025-08-10T23:13Z. The source location is best (although faintly) seen in EUVI A 304 as an eruption of a long filament stretched between AR 14173 (which is nearing the limb in SDO AIA) and AR 14161 (~20 degrees further west), far behind the limb as seen from SDO.', 'submissionTime': '2025-08-11T02:58Z', 'versionId': 1, 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/40521/-1', 'cmeAnalyses': [{'isMostAccurate': True, 'time21_5': '2025-08-11T05:05Z', 'latitude': -31.0, 'longitude': 109.0, 'halfAngle': 27.0, 'speed': 648.0, 'type': 'C', 'featureCode': 'LE', 'imageType': 'running difference', 'measurementTechnique': 'SWPC_CAT', 'note': 'Analysis based on the fit with two coronagraphs (SOHO LASCO C2/C3 and STEREO A COR2) and confirmed by location of the far-sided source, as seen from EUVI A.', 'levelOfData': 0, 'tilt': None, 'minorHalfWidth': None, 'speedMeasuredAtHeight': None, 'submissionTime': '2025-08-11T03:00Z', 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/40522/-1', 'enlilList': [{'modelCompletionTime': '2025-08-11T02:52Z', 'au': 2.0, 'estimatedShockArrivalTime': None, 'estimatedDuration': None, 'rmin_re': None, 'kp_18': None, 'kp_90': None, 'kp_135': None, 'kp_180': None, 'isEarthGB': False, 'isEarthMinorImpact': False, 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/40523/-1', 'impactList': [{'isGlancingBlow': False, 'isMinorImpact': True, 'location': 'Juice', 'arrivalTime': '2025-08-13T03:00Z'}], 'cmeIDs': ['2025-08-10T23:48:00-CME-001']}]}], 'linkedEvents': None, 'sentNotifications': [{'messageID': '20250811-AL-001', 'messageIssueTime': '2025-08-11T03:08Z', 'messageURL': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/Alert/40524/1'}]}, {'activityID': '2025-08-11T05:00:00-CME-001', 'catalog': 'M2M_CATALOG', 'startTime': '2025-08-11T05:00Z', 'instruments': [{'displayName': 'SOHO: LASCO/C2'}, {'displayName': 'SOHO: LASCO/C3'}, {'displayName': 'STEREO A: SECCHI/COR2'}, {'displayName': 'GOES: CCOR-1'}], 'sourceLocation': '', 'activeRegionNum': None, 'note': 'This CME is visible to the SW in SOHO LASCO C2/C3, GOES CCOR-1, and STEREO A COR2 imagery. The source appears to be a faint filament eruption and quick moving/opening field lines on/just beyond the W/SW limb in GOES SUVI 284 and 304 starting around 2025-08-11T04:30Z.', 'submissionTime': '2025-08-11T13:45Z', 'versionId': 1, 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/40526/-1', 'cmeAnalyses': [{'isMostAccurate': True, 'time21_5': '2025-08-11T11:14Z', 'latitude': -18.0, 'longitude': 118.0, 'halfAngle': 26.0, 'speed': 576.0, 'type': 'C', 'featureCode': 'LE', 'imageType': 'running difference', 'measurementTechnique': 'SWPC_CAT', 'note': 'Parameters based on best fit using SOHO LASCO C3, STEREO A COR2, and GOES CCOR-1 imagery.', 'levelOfData': 0, 'tilt': None, 'minorHalfWidth': None, 'speedMeasuredAtHeight': 13.9, 'submissionTime': '2025-08-11T13:46Z', 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/40527/-1', 'enlilList': [{'modelCompletionTime': '2025-08-11T14:05Z', 'au': 2.0, 'estimatedShockArrivalTime': None, 'estimatedDuration': None, 'rmin_re': None, 'kp_18': None, 'kp_90': None, 'kp_135': None, 'kp_180': None, 'isEarthGB': False, 'isEarthMinorImpact': False, 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/40528/-1', 'impactList': [{'isGlancingBlow': True, 'isMinorImpact': False, 'location': 'Juice', 'arrivalTime': '2025-08-13T08:00Z'}], 'cmeIDs': ['2025-08-11T05:00:00-CME-001']}]}], 'linkedEvents': None, 'sentNotifications': [{'messageID': '20250811-AL-002', 'messageIssueTime': '2025-08-11T14:50Z', 'messageURL': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/Alert/40529/1'}]}, {'activityID': '2025-08-11T05:12:00-CME-001', 'catalog': 'M2M_CATALOG', 'startTime': '2025-08-11T05:12Z', 'instruments': [{'displayName': 'SOHO: LASCO/C2'}, {'displayName': 'SOHO: LASCO/C3'}, {'displayName': 'STEREO A: SECCHI/COR2'}, {'displayName': 'GOES: CCOR-1'}], 'sourceLocation': 'S10E71', 'activeRegionNum': 14179, 'note': 'Narrow jet-like CME seen to the SE in SOHO LASCO C2/C3, STEREO A COR2, and GOES CCOR-1. The source is likely a quick eruption from AR 14179 (S10E71), seen as a small amount of ejecta and brightening starting around 2025-08-11T04:48Z in SDO AIA 304 and GOES SUVI 304.', 'submissionTime': '2025-08-11T18:41Z', 'versionId': 1, 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/40535/-1', 'cmeAnalyses': [{'isMostAccurate': True, 'time21_5': '2025-08-11T08:42Z', 'latitude': -9.0, 'longitude': -61.0, 'halfAngle': 10.0, 'speed': 989.0, 'type': 'C', 'featureCode': 'LE', 'imageType': 'running difference', 'measurementTechnique': 'SWPC_CAT', 'note': 'Measurement of faint leading edge using knowledge of source location and best fit between a handful of frames of SOHO LASCO C2/C3, STEREO A COR2, and one frame of GOES CCOR-1.', 'levelOfData': 0, 'tilt': None, 'minorHalfWidth': None, 'speedMeasuredAtHeight': 11.0, 'submissionTime': '2025-08-11T18:45Z', 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/40536/-1', 'enlilList': [{'modelCompletionTime': '2025-08-11T19:22Z', 'au': 2.0, 'estimatedShockArrivalTime': None, 'estimatedDuration': None, 'rmin_re': None, 'kp_18': None, 'kp_90': None, 'kp_135': None, 'kp_180': None, 'isEarthGB': False, 'isEarthMinorImpact': False, 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/40538/-1', 'impactList': None, 'cmeIDs': ['2025-08-11T05:12:00-CME-001']}, {'modelCompletionTime': '2025-08-11T19:40Z', 'au': 5.5, 'estimatedShockArrivalTime': None, 'estimatedDuration': None, 'rmin_re': None, 'kp_18': None, 'kp_90': None, 'kp_135': None, 'kp_180': None, 'isEarthGB': False, 'isEarthMinorImpact': False, 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/40539/-1', 'impactList': [{'isGlancingBlow': True, 'isMinorImpact': False, 'location': 'Psyche', 'arrivalTime': '2025-08-17T20:00Z'}], 'cmeIDs': ['2025-08-11T05:12:00-CME-001']}]}], 'linkedEvents': None, 'sentNotifications': [{'messageID': '20250811-AL-003', 'messageIssueTime': '2025-08-11T20:38Z', 'messageURL': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/Alert/40540/1'}]}, {'activityID': '2025-08-11T09:53:00-CME-001', 'catalog': 'M2M_CATALOG', 'startTime': '2025-08-11T09:53Z', 'instruments': [{'displayName': 'STEREO A: SECCHI/COR2'}, {'displayName': 'SOHO: LASCO/C3'}, {'displayName': 'GOES: CCOR-1'}], 'sourceLocation': '', 'activeRegionNum': None, 'note': "This CME is visible to the SW in STEREO A COR2, GOES CCOR-1, and SOHO LASCO C2/C3 imagery following a data backfill. There was a data gap in real-time for this CME in SOHO LASCO imagery. There isn't a clear source, however multiple moving/opening field lines are visible along the SW limb in GOES SUVI 284 starting around 2025-08-11T08:30Z.", 'submissionTime': '2025-08-12T15:27Z', 'versionId': 3, 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/40533/-1', 'cmeAnalyses': [{'isMostAccurate': True, 'time21_5': '2025-08-11T15:09Z', 'latitude': -49.0, 'longitude': 155.0, 'halfAngle': 32.0, 'speed': 728.0, 'type': 'C', 'featureCode': 'LE', 'imageType': 'running difference', 'measurementTechnique': 'SWPC_CAT', 'note': 'Parameters based on best fit using SOHO LASCO C3 and STEREO A COR2 imagery. The front is too diffuse/faint to use in GOES CCOR-1 imagery.', 'levelOfData': 0, 'tilt': None, 'minorHalfWidth': None, 'speedMeasuredAtHeight': 12.7, 'submissionTime': '2025-08-11T18:31Z', 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/40534/-1', 'enlilList': [{'modelCompletionTime': '2025-08-11T21:41Z', 'au': 2.0, 'estimatedShockArrivalTime': None, 'estimatedDuration': None, 'rmin_re': None, 'kp_18': None, 'kp_90': None, 'kp_135': None, 'kp_180': None, 'isEarthGB': False, 'isEarthMinorImpact': False, 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/40541/-1', 'impactList': [{'isGlancingBlow': True, 'isMinorImpact': False, 'location': 'Solar Orbiter', 'arrivalTime': '2025-08-13T05:00Z'}], 'cmeIDs': ['2025-08-11T09:53:00-CME-001']}]}], 'linkedEvents': None, 'sentNotifications': [{'messageID': '20250811-AL-004', 'messageIssueTime': '2025-08-11T22:23Z', 'messageURL': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/Alert/40542/1'}]}, {'activityID': '2025-08-11T16:48:00-CME-001', 'catalog': 'M2M_CATALOG', 'startTime': '2025-08-11T16:48Z', 'instruments': [{'displayName': 'SOHO: LASCO/C2'}, {'displayName': 'SOHO: LASCO/C3'}, {'displayName': 'STEREO A: SECCHI/COR2'}, {'displayName': 'GOES: CCOR-1'}], 'sourceLocation': 'N05W90', 'activeRegionNum': 14168, 'note': 'This CME is visible to the west in SOHO LASCO C2/C3, GOES COR-1, and STEREO A COR2 imagery. The source is an M1.6 flare and eruption from Active Region 14168 (N05W90) starting around 2025-08-11T15:30Z as seen in SDO AIA 131, 171, 193, 304 imagery. An opening of field lines is visible over the western limb in GOES SUVI 284 imagery, and post-eruptive arcades are visible in SDO AIA 171 and 193 imagery starting around 2025-08-11T17:00Z.', 'submissionTime': '2025-08-12T00:03Z', 'versionId': 1, 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/40544/-1', 'cmeAnalyses': [{'isMostAccurate': True, 'time21_5': '2025-08-11T23:19Z', 'latitude': -7.0, 'longitude': 94.0, 'halfAngle': 19.0, 'speed': 556.0, 'type': 'C', 'featureCode': 'LE', 'imageType': 'running difference', 'measurementTechnique': 'SWPC_CAT', 'note': 'Measurement based on the approximate source location and best fit between SOHO LASCO C2/C3, GOES CCOR-1, and STEREO A COR2 imagery.', 'levelOfData': 0, 'tilt': None, 'minorHalfWidth': None, 'speedMeasuredAtHeight': 8.4, 'submissionTime': '2025-08-12T00:05Z', 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/40545/-1', 'enlilList': [{'modelCompletionTime': '2025-08-12T00:23Z', 'au': 2.0, 'estimatedShockArrivalTime': None, 'estimatedDuration': None, 'rmin_re': None, 'kp_18': None, 'kp_90': None, 'kp_135': None, 'kp_180': None, 'isEarthGB': False, 'isEarthMinorImpact': False, 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/40546/-1', 'impactList': [{'isGlancingBlow': False, 'isMinorImpact': False, 'location': 'Juice', 'arrivalTime': '2025-08-13T18:43Z'}], 'cmeIDs': ['2025-08-11T16:48:00-CME-001']}]}], 'linkedEvents': [{'activityID': '2025-08-11T15:18:00-FLR-001'}], 'sentNotifications': [{'messageID': '20250812-AL-001', 'messageIssueTime': '2025-08-12T00:57Z', 'messageURL': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/Alert/40547/1'}]}, {'activityID': '2025-08-11T20:12:00-CME-001', 'catalog': 'M2M_CATALOG', 'startTime': '2025-08-11T20:12Z', 'instruments': [{'displayName': 'SOHO: LASCO/C2'}, {'displayName': 'SOHO: LASCO/C3'}, {'displayName': 'STEREO A: SECCHI/COR2'}, {'displayName': 'GOES: CCOR-1'}], 'sourceLocation': 'S60W30', 'activeRegionNum': None, 'note': 'This CME is visible to the south in SOHO LASCO C2/C3, GOES CCOR-1, and STEREO A COR2 imagery. The source is likely related to a large filament eruption spanning S60E05 to S50W50 which begins to slowly lift off around 2025-08-11T18:00Z as seen in SDO AIA 131, 171, 193, 304 imagery. An opening of field lines is visible over the southern limb in GOES SUVI 284 imagery, and post eruptive arcades begin to form around 2025-08-11T20:00Z as seen in SDO AIA 171 and 193 imagery.', 'submissionTime': '2025-08-12T01:38Z', 'versionId': 1, 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/40549/-1', 'cmeAnalyses': [{'isMostAccurate': True, 'time21_5': '2025-08-12T02:15Z', 'latitude': -72.0, 'longitude': 40.0, 'halfAngle': 17.0, 'speed': 578.0, 'type': 'C', 'featureCode': 'LE', 'imageType': 'running difference', 'measurementTechnique': 'SWPC_CAT', 'note': 'Measurement based on the approximate source location and best fit between SOHO LASCO C3, GOES CCOR-1, and STEREO A COR2 imagery.', 'levelOfData': 0, 'tilt': None, 'minorHalfWidth': None, 'speedMeasuredAtHeight': 9.5, 'submissionTime': '2025-08-12T01:40Z', 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/40550/-1', 'enlilList': []}], 'linkedEvents': None, 'sentNotifications': None}, {'activityID': '2025-08-12T01:45:00-CME-001', 'catalog': 'M2M_CATALOG', 'startTime': '2025-08-12T01:45Z', 'instruments': [{'displayName': 'GOES: CCOR-1'}, {'displayName': 'STEREO A: SECCHI/COR2'}], 'sourceLocation': 'N06W90', 'activeRegionNum': 14168, 'note': 'Narrow CME seen to the W in STEREO A COR2 and GOES CCOR-1. Source is a small eruption and associated M1.8 flare from AR 14168 (N06W90) seen starting at 2025-08-12T01:26Z in SDO AIA 131 and GOES SUVI 304. This CME is not captured in SOHO LASCO C2/C3 imagery due to a data gap in SOHO LASCO lasting from 2025-08-12T00:54Z to 2025-08-12T04:40Z.', 'submissionTime': '2025-08-12T12:42Z', 'versionId': 1, 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/40552/-1', 'cmeAnalyses': [{'isMostAccurate': True, 'time21_5': '2025-08-12T05:26Z', 'latitude': 4.0, 'longitude': 90.0, 'halfAngle': 10.0, 'speed': 876.0, 'type': 'C', 'featureCode': 'LE', 'imageType': 'running difference', 'measurementTechnique': 'SWPC_CAT', 'note': 'Best fit measurement using several frames of GOES CCOR-1 and STEREO A COR2. This CME is not captured in SOHO LASCO C2/C3 imagery due to a data gap in SOHO LASCO lasting from 2025-08-12T00:54Z to 2025-08-12T04:40Z.', 'levelOfData': 0, 'tilt': None, 'minorHalfWidth': None, 'speedMeasuredAtHeight': 11.0, 'submissionTime': '2025-08-12T12:45Z', 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/40553/-1', 'enlilList': [{'modelCompletionTime': '2025-08-12T13:06Z', 'au': 2.0, 'estimatedShockArrivalTime': None, 'estimatedDuration': None, 'rmin_re': None, 'kp_18': None, 'kp_90': None, 'kp_135': None, 'kp_180': None, 'isEarthGB': False, 'isEarthMinorImpact': False, 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/40554/-1', 'impactList': [{'isGlancingBlow': False, 'isMinorImpact': False, 'location': 'Juice', 'arrivalTime': '2025-08-13T21:53Z'}], 'cmeIDs': ['2025-08-12T01:45:00-CME-001']}]}], 'linkedEvents': [{'activityID': '2025-08-12T01:18:00-FLR-001'}], 'sentNotifications': [{'messageID': '20250812-AL-002', 'messageIssueTime': '2025-08-12T13:41Z', 'messageURL': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/Alert/40555/1'}]}, {'activityID': '2025-08-12T08:53:00-CME-001', 'catalog': 'M2M_CATALOG', 'startTime': '2025-08-12T08:53Z', 'instruments': [{'displayName': 'STEREO A: SECCHI/COR2'}], 'sourceLocation': 'N05W96', 'activeRegionNum': 14168, 'note': 'CME first seen to the NW in STEREO A COR2 starting at 2025-08-12T08:53Z. This CME is not seen in SOHO LASCO C2/C3 or GOES CCOR-1. The CME dissipates before reaching the end of the FOV of STEREO A COR2. A possible source candidate for this CME is an eruption from former AR 14168 best seen in STEREO A EUVI 195 beginning around 2025-08-12T04:05Z.', 'submissionTime': '2025-08-12T22:14Z', 'versionId': 1, 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/40565/-1', 'cmeAnalyses': [{'isMostAccurate': True, 'time21_5': '2025-08-12T18:00Z', 'latitude': 22.0, 'longitude': 96.0, 'halfAngle': 20.0, 'speed': 382.0, 'type': 'S', 'featureCode': 'LE', 'imageType': 'running difference', 'measurementTechnique': 'SWPC_CAT', 'note': 'Measurement based on source signature from former AR 14168 (~N05W96). There is a significant amount of uncertainty in this measurement due to the lack of triangulation and the proximity of the source to a large coronal hole.', 'levelOfData': 0, 'tilt': None, 'minorHalfWidth': None, 'speedMeasuredAtHeight': None, 'submissionTime': '2025-08-12T22:16Z', 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/40566/-1', 'enlilList': [{'modelCompletionTime': '2025-08-12T22:41Z', 'au': 2.0, 'estimatedShockArrivalTime': None, 'estimatedDuration': None, 'rmin_re': None, 'kp_18': None, 'kp_90': None, 'kp_135': None, 'kp_180': None, 'isEarthGB': False, 'isEarthMinorImpact': False, 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/40567/-1', 'impactList': [{'isGlancingBlow': True, 'isMinorImpact': False, 'location': 'BepiColombo', 'arrivalTime': '2025-08-13T22:00Z'}, {'isGlancingBlow': True, 'isMinorImpact': False, 'location': 'Juice', 'arrivalTime': '2025-08-15T02:00Z'}], 'cmeIDs': ['2025-08-12T08:53:00-CME-001']}]}], 'linkedEvents': None, 'sentNotifications': None}, {'activityID': '2025-08-12T13:25:00-CME-001', 'catalog': 'M2M_CATALOG', 'startTime': '2025-08-12T13:25Z', 'instruments': [{'displayName': 'SOHO: LASCO/C2'}, {'displayName': 'SOHO: LASCO/C3'}, {'displayName': 'STEREO A: SECCHI/COR2'}, {'displayName': 'GOES: CCOR-1'}], 'sourceLocation': 'N05W98', 'activeRegionNum': 14168, 'note': 'Faint and narrow CME first seen to the West in SOHO LASCO C2 beginning at 2025-08-12T13:25Z, as well as by SOHO LASCO C3, STEREO A COR2 and GOES CCOR-1 in later frames. The source of this event is a C6.1 flare from AR14168 (N05W98) peaking at 2025-08-12T12:18Z. This flare is visible in SSO AIA 131, along with field line opening seen in SDO AIA 171, 193 and GOES SUVI 284.', 'submissionTime': '2025-08-12T18:57Z', 'versionId': 1, 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/40559/-1', 'cmeAnalyses': [{'isMostAccurate': True, 'time21_5': '2025-08-12T19:39Z', 'latitude': -1.0, 'longitude': 98.0, 'halfAngle': 10.0, 'speed': 520.0, 'type': 'C', 'featureCode': 'LE', 'imageType': 'running difference', 'measurementTechnique': 'SWPC_CAT', 'note': 'Measurement based on approximate source location and best fit in SOHO LASCO C2/C3, STEREO A COR2 and GOES CCOR-1.', 'levelOfData': 0, 'tilt': None, 'minorHalfWidth': None, 'speedMeasuredAtHeight': None, 'submissionTime': '2025-08-12T18:58Z', 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/40560/-1', 'enlilList': [{'modelCompletionTime': '2025-08-12T19:19Z', 'au': 2.0, 'estimatedShockArrivalTime': None, 'estimatedDuration': None, 'rmin_re': None, 'kp_18': None, 'kp_90': None, 'kp_135': None, 'kp_180': None, 'isEarthGB': False, 'isEarthMinorImpact': False, 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/40563/-1', 'impactList': [{'isGlancingBlow': True, 'isMinorImpact': False, 'location': 'Juice', 'arrivalTime': '2025-08-14T15:00Z'}], 'cmeIDs': ['2025-08-12T13:25:00-CME-001']}]}], 'linkedEvents': [{'activityID': '2025-08-12T12:03:00-FLR-001'}], 'sentNotifications': [{'messageID': '20250812-AL-004', 'messageIssueTime': '2025-08-12T19:37Z', 'messageURL': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/Alert/40564/1'}]}, {'activityID': '2025-08-12T18:00:00-CME-001', 'catalog': 'M2M_CATALOG', 'startTime': '2025-08-12T18:00Z', 'instruments': [{'displayName': 'SOHO: LASCO/C2'}, {'displayName': 'SOHO: LASCO/C3'}, {'displayName': 'STEREO A: SECCHI/COR2'}, {'displayName': 'GOES: CCOR-1'}], 'sourceLocation': '', 'activeRegionNum': None, 'note': 'Faint CME seen to the west in SOHO LASCO C2/C3, STEREO A COR2, and GOES CCOR-1. The source is not clear, but may be some field line movement seen in SDO AIA 171 in ISWA around 2025-08-12T16:43Z. Minor eruptive activity is also seen near the west limb in STEREO A EUV 195 imagery from around 2025-08-12T14:00Z-17:00Z.', 'submissionTime': '2025-08-13T12:56Z', 'versionId': 1, 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/40568/-1', 'cmeAnalyses': [{'isMostAccurate': True, 'time21_5': '2025-08-13T04:10Z', 'latitude': -8.0, 'longitude': 93.0, 'halfAngle': 14.0, 'speed': 320.0, 'type': 'S', 'featureCode': 'LE', 'imageType': 'running difference', 'measurementTechnique': 'SWPC_CAT', 'note': "Measurement based on best fit between SOHO LASCO C2/C3, STEREO A COR2, and GOES CCOR-1 in SWPC_CAT. Limited imagery was used due to the CME's faintness.", 'levelOfData': 0, 'tilt': None, 'minorHalfWidth': None, 'speedMeasuredAtHeight': 8.3, 'submissionTime': '2025-08-13T12:57Z', 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/40569/-1', 'enlilList': [{'modelCompletionTime': '2025-08-13T16:41Z', 'au': 2.0, 'estimatedShockArrivalTime': None, 'estimatedDuration': None, 'rmin_re': None, 'kp_18': None, 'kp_90': None, 'kp_135': None, 'kp_180': None, 'isEarthGB': False, 'isEarthMinorImpact': False, 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/40572/-1', 'impactList': [{'isGlancingBlow': True, 'isMinorImpact': False, 'location': 'Juice', 'arrivalTime': '2025-08-15T10:00Z'}], 'cmeIDs': ['2025-08-12T18:00:00-CME-001']}]}], 'linkedEvents': None, 'sentNotifications': None}, {'activityID': '2025-08-13T18:00:00-CME-001', 'catalog': 'M2M_CATALOG', 'startTime': '2025-08-13T18:00Z', 'instruments': [{'displayName': 'SOHO: LASCO/C2'}, {'displayName': 'SOHO: LASCO/C3'}, {'displayName': 'STEREO A: SECCHI/COR2'}, {'displayName': 'GOES: CCOR-1'}], 'sourceLocation': '', 'activeRegionNum': None, 'note': 'Narrow CME first seen to the South in SOHO LASCO C2 beginning at 2025-08-13T18:00Z, as well as by SOHO LASCO C3, STEREO A COR2 and GOES CCOR-1 in later frames. The source of this event is a minor filament eruption seen along the South limb beginning at approx. 2025-08-13T16:34Z. This eruption is visible in SDO AIA, GOES SUVI and STEREO A EUVI 304, along with field line opening seen in SDO AIA 193 and GOES SUVI 284.', 'submissionTime': '2025-08-13T20:55Z', 'versionId': 1, 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/40574/-1', 'cmeAnalyses': [{'isMostAccurate': True, 'time21_5': '2025-08-14T01:09Z', 'latitude': -74.0, 'longitude': 71.0, 'halfAngle': 10.0, 'speed': 504.0, 'type': 'C', 'featureCode': 'LE', 'imageType': 'running difference', 'measurementTechnique': 'SWPC_CAT', 'note': 'Measurement based on approximate source location and best fit in SOHO LASCO C2, STEREO A COR2 and GOES CCOR-1.', 'levelOfData': 0, 'tilt': None, 'minorHalfWidth': None, 'speedMeasuredAtHeight': None, 'submissionTime': '2025-08-13T20:57Z', 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/40575/-1', 'enlilList': []}], 'linkedEvents': None, 'sentNotifications': None}, {'activityID': '2025-08-13T20:23:00-CME-001', 'catalog': 'M2M_CATALOG', 'startTime': '2025-08-13T20:23Z', 'instruments': [{'displayName': 'STEREO A: SECCHI/COR2'}, {'displayName': 'GOES: CCOR-1'}], 'sourceLocation': 'S08W100', 'activeRegionNum': 14174, 'note': 'CME first seen to the West by STEREO A COR2 beginning at 2025-08-13T20:23Z, as well as by GOES CCOR-1 in later frames. The source of this event is a C4.3 flare from Active Region 14172 (S08W100) peaking at 2025-08-13T19:39Z. This flare is visible in SDO AIA 131, along with dimming and field line opening seen in SDO AIA 193, 211 and STEREO A EUVI 195.', 'submissionTime': '2025-08-13T22:29Z', 'versionId': 1, 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/40577/-1', 'cmeAnalyses': [{'isMostAccurate': True, 'time21_5': '2025-08-13T23:27Z', 'latitude': -7.0, 'longitude': 107.0, 'halfAngle': 20.0, 'speed': 1014.0, 'type': 'O', 'featureCode': 'LE', 'imageType': 'running difference', 'measurementTechnique': 'SWPC_CAT', 'note': 'Measurement based on approximate source location and best fit between STEREO A COR2 and GOES CCOR-1.', 'levelOfData': 0, 'tilt': None, 'minorHalfWidth': None, 'speedMeasuredAtHeight': None, 'submissionTime': '2025-08-13T22:30Z', 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/40578/-1', 'enlilList': [{'modelCompletionTime': '2025-08-13T22:50Z', 'au': 2.0, 'estimatedShockArrivalTime': None, 'estimatedDuration': None, 'rmin_re': None, 'kp_18': None, 'kp_90': None, 'kp_135': None, 'kp_180': None, 'isEarthGB': False, 'isEarthMinorImpact': False, 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/40579/-1', 'impactList': [{'isGlancingBlow': False, 'isMinorImpact': False, 'location': 'Juice', 'arrivalTime': '2025-08-15T08:44Z'}], 'cmeIDs': ['2025-08-13T20:23:00-CME-001']}, {'modelCompletionTime': '2025-08-13T23:31Z', 'au': 5.5, 'estimatedShockArrivalTime': None, 'estimatedDuration': None, 'rmin_re': None, 'kp_18': None, 'kp_90': None, 'kp_135': None, 'kp_180': None, 'isEarthGB': False, 'isEarthMinorImpact': False, 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/40580/-1', 'impactList': [{'isGlancingBlow': False, 'isMinorImpact': False, 'location': 'Juice', 'arrivalTime': '2025-08-15T08:21Z'}, {'isGlancingBlow': True, 'isMinorImpact': False, 'location': 'Juno', 'arrivalTime': '2025-08-28T00:00Z'}], 'cmeIDs': ['2025-08-13T20:23:00-CME-001']}]}], 'linkedEvents': [{'activityID': '2025-08-13T19:14:00-FLR-001'}], 'sentNotifications': [{'messageID': '20250813-AL-001', 'messageIssueTime': '2025-08-13T23:41Z', 'messageURL': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/Alert/40581/1'}]}, {'activityID': '2025-08-13T23:00:00-CME-001', 'catalog': 'M2M_CATALOG', 'startTime': '2025-08-13T23:00Z', 'instruments': [{'displayName': 'SOHO: LASCO/C2'}, {'displayName': 'STEREO A: SECCHI/COR2'}, {'displayName': 'GOES: CCOR-1'}], 'sourceLocation': 'N27W55', 'activeRegionNum': None, 'note': 'Faint, hazy CME first seen to the NE in SOHO LASCO C2 beginning at 2025-08-13T23:00Z, as well as by STEREO A COR2 and GOES CCOR-1 in later frames. The source of this event is a minor eruption seen beginning at approx. 2025-08-13T22:21Z, centered at approx. N27E55. This eruption is visible in SDO AIA 193, along with brightening and post eruptive arcades seen in SDO AIA 94. This CME is likely deflected towards the East due to proximity to a coronal hole.', 'submissionTime': '2025-08-14T00:53Z', 'versionId': 1, 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/40582/-1', 'cmeAnalyses': [{'isMostAccurate': True, 'time21_5': '2025-08-14T12:16Z', 'latitude': 26.0, 'longitude': -80.0, 'halfAngle': 25.0, 'speed': 270.0, 'type': 'S', 'featureCode': 'LE', 'imageType': 'running difference', 'measurementTechnique': 'SWPC_CAT', 'note': 'Measurement based on approximate source location and best fit between SOHO LASCO C2 and STEREO A COR2.', 'levelOfData': 0, 'tilt': None, 'minorHalfWidth': None, 'speedMeasuredAtHeight': None, 'submissionTime': '2025-08-14T00:54Z', 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/40583/-1', 'enlilList': [{'modelCompletionTime': '2025-08-14T01:13Z', 'au': 2.0, 'estimatedShockArrivalTime': None, 'estimatedDuration': None, 'rmin_re': None, 'kp_18': None, 'kp_90': None, 'kp_135': None, 'kp_180': None, 'isEarthGB': False, 'isEarthMinorImpact': False, 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/40584/-1', 'impactList': None, 'cmeIDs': ['2025-08-13T23:00:00-CME-001']}, {'modelCompletionTime': '2025-08-14T01:54Z', 'au': 5.5, 'estimatedShockArrivalTime': None, 'estimatedDuration': None, 'rmin_re': None, 'kp_18': None, 'kp_90': None, 'kp_135': None, 'kp_180': None, 'isEarthGB': False, 'isEarthMinorImpact': False, 'link': 'https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/40585/-1', 'impactList': [{'isGlancingBlow': True, 'isMinorImpact': False, 'location': 'Psyche', 'arrivalTime': '2025-08-23T12:00Z'}], 'cmeIDs': ['2025-08-13T23:00:00-CME-001']}]}], 'linkedEvents': None, 'sentNotifications': None}]

# %%
df = pd.json_normalize(data)
df.head(3)
# Out:
#                     activityID      catalog          startTime  \
# 0  2025-08-10T02:12:00-CME-001  M2M_CATALOG  2025-08-10T02:12Z
# 1  2025-08-10T04:12:00-CME-001  M2M_CATALOG  2025-08-10T04:12Z
# 2  2025-08-10T15:24:00-CME-001  M2M_CATALOG  2025-08-10T15:24Z
#
#                                          instruments sourceLocation  \
# 0  [{'displayName': 'SOHO: LASCO/C2'}, {'displayN...
# 1  [{'displayName': 'SOHO: LASCO/C2'}, {'displayN...         N09E08
# 2  [{'displayName': 'SOHO: LASCO/C2'}, {'displayN...         N05W75
#
#    activeRegionNum                                               note  \
# 0              NaN  Very minor CME seen to the west in SOHO LASCO ...
# 1          14172.0  CME seen to the east in SOHO LASCO C2 and as w...
# 2          14168.0  Asymmetric CME associated with the long-durati...
#
#       submissionTime  versionId  \
# 0  2025-08-11T13:02Z          2
# 1  2025-08-11T13:03Z          2
# 2  2025-08-11T15:28Z          2
#
# ...

# %%
# remove list type from nested json columns
df['cmeAnalyses'] = df['cmeAnalyses'].apply(lambda x: x[0] if x != None else None) # get first list element (list only has 1 element)

# df['linkedEvents'] = df['linkedEvents'].apply(lambda x: x[0] if x != None else None)
df.head(3)
# Out:
#                     activityID      catalog          startTime  \
# 0  2025-08-10T02:12:00-CME-001  M2M_CATALOG  2025-08-10T02:12Z
# 1  2025-08-10T04:12:00-CME-001  M2M_CATALOG  2025-08-10T04:12Z
# 2  2025-08-10T15:24:00-CME-001  M2M_CATALOG  2025-08-10T15:24Z
#
#                                          instruments sourceLocation  \
# 0  [{'displayName': 'SOHO: LASCO/C2'}, {'displayN...
# 1  [{'displayName': 'SOHO: LASCO/C2'}, {'displayN...         N09E08
# 2  [{'displayName': 'SOHO: LASCO/C2'}, {'displayN...         N05W75
#
#    activeRegionNum                                               note  \
# 0              NaN  Very minor CME seen to the west in SOHO LASCO ...
# 1          14172.0  CME seen to the east in SOHO LASCO C2 and as w...
# 2          14168.0  Asymmetric CME associated with the long-durati...
#
#       submissionTime  versionId  \
# 0  2025-08-11T13:02Z          2
# 1  2025-08-11T13:03Z          2
# 2  2025-08-11T15:28Z          2
#
# ...

# %%
fr = df[['activityID', 'cmeAnalyses']]
# fr = fr.rename(columns = {'cmeAnalysis': 'analysis'})
fr.head()
# Out:
#                     activityID  \
# 0  2025-08-10T02:12:00-CME-001
# 1  2025-08-10T04:12:00-CME-001
# 2  2025-08-10T15:24:00-CME-001
# 3  2025-08-10T19:36:00-CME-001
# 4  2025-08-10T23:48:00-CME-001
#
#                                          cmeAnalyses
# 0  {'isMostAccurate': True, 'time21_5': '2025-08-...
# 1  {'isMostAccurate': True, 'time21_5': '2025-08-...
# 2  {'isMostAccurate': True, 'time21_5': '2025-08-...
# 3  {'isMostAccurate': True, 'time21_5': '2025-08-...
# 4  {'isMostAccurate': True, 'time21_5': '2025-08-...

# %%
fr = pd.json_normalize(fr.to_dict(orient='records')) # normalize expects json input so we convert back to dict
fr = fr.rename(columns=lambda x: x.replace('cmeAnalyses.', ''))
fr.head()
# Out:
#                     activityID  isMostAccurate           time21_5  latitude  \
# 0  2025-08-10T02:12:00-CME-001            True  2025-08-10T15:10Z     -18.0
# 1  2025-08-10T04:12:00-CME-001            True  2025-08-10T13:56Z       6.0
# 2  2025-08-10T15:24:00-CME-001            True  2025-08-10T20:08Z      11.0
# 3  2025-08-10T19:36:00-CME-001            True  2025-08-11T03:12Z     -12.0
# 4  2025-08-10T23:48:00-CME-001            True  2025-08-11T05:05Z     -31.0
#
#    longitude  halfAngle  speed type featureCode           imageType  \
# 0       95.0       26.0  274.0    S          LE  running difference
# 1      -39.0       14.0  330.0    S          LE  running difference
# 2       76.0       38.0  741.0    C          LE  running difference
# 3       95.0       10.0  474.0    S          LE  running difference
# 4      109.0       27.0  648.0    C          LE  running difference
#
#   measurementTechnique                                               note  \
# ...

# %%
fs = fr[['activityID', 'enlilList']].copy() # to avoid pandas warning- working on subsets better to explixly use copy
fs['enlilList'] = fs['enlilList'].apply(lambda x: x[0] if x != [] else None)
fs = pd.json_normalize(fs.to_dict(orient='records'))
fs = fs.rename(columns=lambda x: x.replace('enlilList.', 'enlil.'))
fs.head()
# Out:
#                     activityID enlil.modelCompletionTime  enlil.au  \
# 0  2025-08-10T02:12:00-CME-001         2025-08-10T14:14Z       2.0
# 1  2025-08-10T04:12:00-CME-001         2025-08-10T15:00Z       2.0
# 2  2025-08-10T15:24:00-CME-001         2025-08-10T18:45Z       2.0
# 3  2025-08-10T19:36:00-CME-001                       NaN       NaN
# 4  2025-08-10T23:48:00-CME-001         2025-08-11T02:52Z       2.0
#
#    enlil.estimatedShockArrivalTime  enlil.estimatedDuration  enlil.rmin_re  \
# 0                              NaN                      NaN            NaN
# 1                              NaN                      NaN            NaN
# 2                              NaN                      NaN            NaN
# 3                              NaN                      NaN            NaN
# 4                              NaN                      NaN            NaN
#
#    enlil.kp_18  enlil.kp_90  enlil.kp_135  enlil.kp_180 enlil.isEarthGB  \
# ...

# %%
df = df.merge(fr, on='activityID', how='inner')
df = df.merge(fs, on='activityID', how='inner')
df.head()
# Out:
#                     activityID      catalog          startTime  \
# 0  2025-08-10T02:12:00-CME-001  M2M_CATALOG  2025-08-10T02:12Z
# 1  2025-08-10T04:12:00-CME-001  M2M_CATALOG  2025-08-10T04:12Z
# 2  2025-08-10T15:24:00-CME-001  M2M_CATALOG  2025-08-10T15:24Z
# 3  2025-08-10T19:36:00-CME-001  M2M_CATALOG  2025-08-10T19:36Z
# 4  2025-08-10T23:48:00-CME-001  M2M_CATALOG  2025-08-10T23:48Z
#
#                                          instruments sourceLocation  \
# 0  [{'displayName': 'SOHO: LASCO/C2'}, {'displayN...
# 1  [{'displayName': 'SOHO: LASCO/C2'}, {'displayN...         N09E08
# 2  [{'displayName': 'SOHO: LASCO/C2'}, {'displayN...         N05W75
# 3  [{'displayName': 'SOHO: LASCO/C2'}, {'displayN...
# 4  [{'displayName': 'SOHO: LASCO/C2'}, {'displayN...
#
#    activeRegionNum                                             note_x  \
# 0              NaN  Very minor CME seen to the west in SOHO LASCO ...
# 1          14172.0  CME seen to the east in SOHO LASCO C2 and as w...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 46 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   activityID                       17 non-null     object
#  1   catalog                          17 non-null     object
#  2   startTime                        17 non-null     object
#  3   instruments                      17 non-null     object
#  4   sourceLocation                   17 non-null     object
#  5   activeRegionNum                  8 non-null      float64
#  6   note_x                           17 non-null     object
#  7   submissionTime_x                 17 non-null     object
#  8   versionId                        17 non-null     int64
#  9   link_x                           17 non-null     object
#  10  cmeAnalyses                      17 non-null     object
#  11  linkedEvents                     5 non-null      object
# ...

# %%
# startDate=2025-06-10 endDate=2025-08-13
data = [
  {
    "gstID": "2025-06-13T00:00:00-GST-001",
    "startTime": "2025-06-13T00:00Z",
    "allKpIndex": [
      {
        "observedTime": "2025-06-13T03:00Z",
        "kpIndex": 6.33,
        "source": "NOAA"
      },
      {
        "observedTime": "2025-06-13T06:00Z",
        "kpIndex": 5.67,
        "source": "NOAA"
      },
      {
        "observedTime": "2025-06-13T15:00Z",
        "kpIndex": 6,
        "source": "NOAA"
      },
      {
        "observedTime": "2025-06-13T21:00Z",
        "kpIndex": 6,
        "source": "NOAA"
      },
      {
        "observedTime": "2025-06-14T00:00Z",
        "kpIndex": 5.67,
        "source": "NOAA"
      }
    ],
    "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/39452/-1",
    "linkedEvents": [
      {
        "activityID": "2025-06-08T02:48:00-CME-001"
      },
      {
        "activityID": "2025-06-11T11:25:00-IPS-001"
      },
      {
        "activityID": "2025-06-11T11:25:00-HSS-001"
      },
      {
        "activityID": "2025-06-12T19:30:00-IPS-001"
      }
    ],
    "submissionTime": "2025-06-13T03:03Z",
    "versionId": 1,
    "sentNotifications": [
      {
        "messageID": "20250613-AL-001",
        "messageIssueTime": "2025-06-13T03:03Z",
        "messageURL": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/Alert/39453/1"
      },
      {
        "messageID": "20250613-AL-002",
        "messageIssueTime": "2025-06-13T12:31Z",
        "messageURL": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/Alert/39455/1"
      }
    ]
  },
  {
    "gstID": "2025-08-09T15:00:00-GST-001",
    "startTime": "2025-08-09T15:00Z",
    "allKpIndex": [
      {
        "observedTime": "2025-08-09T18:00Z",
        "kpIndex": 6,
        "source": "NOAA"
      }
    ],
    "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/40480/-1",
    "linkedEvents": [
      {
        "activityID": "2025-08-05T16:48:00-CME-001"
      },
      {
        "activityID": "2025-08-08T06:30:00-IPS-001"
      },
      {
        "activityID": "2025-08-08T12:02:00-HSS-001"
      },
      {
        "activityID": "2025-08-08T23:46:00-IPS-001"
      }
    ],
    "submissionTime": "2025-08-09T18:03Z",
    "versionId": 1,
    "sentNotifications": [
      {
        "messageID": "20250809-AL-005",
        "messageIssueTime": "2025-08-09T18:03Z",
        "messageURL": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/Alert/40481/1"
      },
      {
        "messageID": "20250809-AL-006",
        "messageIssueTime": "2025-08-09T18:19Z",
        "messageURL": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/Alert/40482/1"
      }
    ]
  }
]

# %%
df = pd.json_normalize(data)
df.head()
# Out:
#                          gstID          startTime  \
# 0  2025-06-13T00:00:00-GST-001  2025-06-13T00:00Z
# 1  2025-08-09T15:00:00-GST-001  2025-08-09T15:00Z
#
#                                           allKpIndex  \
# 0  [{'observedTime': '2025-06-13T03:00Z', 'kpInde...
# 1  [{'observedTime': '2025-08-09T18:00Z', 'kpInde...
#
#                                                 link  \
# 0  https://webtools.ccmc.gsfc.nasa.gov/DONKI/view...
# 1  https://webtools.ccmc.gsfc.nasa.gov/DONKI/view...
#
#                                         linkedEvents     submissionTime  \
# 0  [{'activityID': '2025-06-08T02:48:00-CME-001'}...  2025-06-13T03:03Z
# 1  [{'activityID': '2025-08-05T16:48:00-CME-001'}...  2025-08-09T18:03Z
#
#    versionId                                  sentNotifications
# 0          1  [{'messageID': '20250613-AL-001', 'messageIssu...
# 1          1  [{'messageID': '20250809-AL-005', 'messageIssu...

# %%
data = [
  {
    "flrID": "2025-08-10T02:46:00-FLR-001",
    "catalog": "M2M_CATALOG",
    "instruments": [
      {
        "displayName": "GOES-P: EXIS 1.0-8.0"
      }
    ],
    "beginTime": "2025-08-10T02:46Z",
    "peakTime": "2025-08-10T03:12Z",
    "endTime": "2025-08-10T03:42Z",
    "classType": "M1.7",
    "sourceLocation": "N05W71",
    "activeRegionNum": 14168,
    "note": "",
    "submissionTime": "2025-08-10T12:26Z",
    "versionId": 1,
    "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/FLR/40498/-1",
    "linkedEvents": None,
    "sentNotifications": None
  },
  {
    "flrID": "2025-08-10T14:57:00-FLR-001",
    "catalog": "M2M_CATALOG",
    "instruments": [
      {
        "displayName": "GOES-P: EXIS 1.0-8.0"
      }
    ],
    "beginTime": "2025-08-10T14:57Z",
    "peakTime": "2025-08-10T15:07Z",
    "endTime": "2025-08-10T15:10Z",
    "classType": "M2.2",
    "sourceLocation": "N05W75",
    "activeRegionNum": 14168,
    "note": "",
    "submissionTime": "2025-08-10T15:53Z",
    "versionId": 1,
    "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/FLR/40506/-1",
    "linkedEvents": [
      {
        "activityID": "2025-08-10T15:24:00-CME-001"
      },
      {
        "activityID": "2025-08-10T16:25:00-SEP-001"
      },
      {
        "activityID": "2025-08-10T16:25:00-SEP-002"
      }
    ],
    "sentNotifications": None
  },
  {
    "flrID": "2025-08-10T22:51:00-FLR-001",
    "catalog": "M2M_CATALOG",
    "instruments": [
      {
        "displayName": "GOES-P: EXIS 1.0-8.0"
      }
    ],
    "beginTime": "2025-08-10T22:51Z",
    "peakTime": "2025-08-10T23:04Z",
    "endTime": "2025-08-10T23:15Z",
    "classType": "M1.7",
    "sourceLocation": "N05W85",
    "activeRegionNum": 14168,
    "note": "",
    "submissionTime": "2025-08-10T23:27Z",
    "versionId": 3,
    "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/FLR/40518/-1",
    "linkedEvents": None,
    "sentNotifications": None
  },
  {
    "flrID": "2025-08-10T23:20:00-FLR-001",
    "catalog": "M2M_CATALOG",
    "instruments": [
      {
        "displayName": "GOES-P: EXIS 1.0-8.0"
      }
    ],
    "beginTime": "2025-08-10T23:20Z",
    "peakTime": "2025-08-10T23:30Z",
    "endTime": "2025-08-10T23:38Z",
    "classType": "M1.0",
    "sourceLocation": "N03W80",
    "activeRegionNum": 14168,
    "note": "Brightening from a simultaneous eruption from AR 14173 (S18W83), best seen in seen in SDO AIA 131, may have contributed to the total intensity of this flare.",
    "submissionTime": "2025-08-12T16:34Z",
    "versionId": 1,
    "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/FLR/40557/-1",
    "linkedEvents": None,
    "sentNotifications": None
  },
  {
    "flrID": "2025-08-11T03:42:00-FLR-001",
    "catalog": "M2M_CATALOG",
    "instruments": [
      {
        "displayName": "GOES-P: EXIS 1.0-8.0"
      }
    ],
    "beginTime": "2025-08-11T03:42Z",
    "peakTime": "2025-08-11T03:52Z",
    "endTime": "2025-08-11T03:59Z",
    "classType": "M1.3",
    "sourceLocation": "S17W90",
    "activeRegionNum": 14173,
    "note": "",
    "submissionTime": "2025-08-11T11:48Z",
    "versionId": 1,
    "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/FLR/40525/-1",
    "linkedEvents": None,
    "sentNotifications": None
  },
  {
    "flrID": "2025-08-11T14:20:00-FLR-001",
    "catalog": "M2M_CATALOG",
    "instruments": [
      {
        "displayName": "GOES-P: EXIS 1.0-8.0"
      }
    ],
    "beginTime": "2025-08-11T14:20Z",
    "peakTime": "2025-08-11T14:35Z",
    "endTime": "2025-08-11T14:57Z",
    "classType": "M1.5",
    "sourceLocation": "N05W86",
    "activeRegionNum": 14168,
    "note": "",
    "submissionTime": "2025-08-11T15:20Z",
    "versionId": 1,
    "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/FLR/40530/-1",
    "linkedEvents": None,
    "sentNotifications": None
  },
  {
    "flrID": "2025-08-11T15:18:00-FLR-001",
    "catalog": "M2M_CATALOG",
    "instruments": [
      {
        "displayName": "GOES-P: EXIS 1.0-8.0"
      }
    ],
    "beginTime": "2025-08-11T15:18Z",
    "peakTime": "2025-08-11T15:36Z",
    "endTime": "2025-08-11T15:51Z",
    "classType": "M1.6",
    "sourceLocation": "N05W90",
    "activeRegionNum": 14168,
    "note": "Simultaneous flaring from Active Region 14173 (~S15W90).",
    "submissionTime": "2025-08-11T16:33Z",
    "versionId": 1,
    "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/FLR/40531/-1",
    "linkedEvents": [
      {
        "activityID": "2025-08-11T16:48:00-CME-001"
      }
    ],
    "sentNotifications": None
  },
  {
    "flrID": "2025-08-11T22:12:00-FLR-001",
    "catalog": "M2M_CATALOG",
    "instruments": [
      {
        "displayName": "GOES-P: EXIS 1.0-8.0"
      }
    ],
    "beginTime": "2025-08-11T22:12Z",
    "peakTime": "2025-08-11T22:18Z",
    "endTime": "2025-08-11T22:22Z",
    "classType": "M1.0",
    "sourceLocation": "N05W90",
    "activeRegionNum": 14168,
    "note": "",
    "submissionTime": "2025-08-11T22:39Z",
    "versionId": 1,
    "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/FLR/40543/-1",
    "linkedEvents": None,
    "sentNotifications": None
  },
  {
    "flrID": "2025-08-12T00:42:00-FLR-001",
    "catalog": "M2M_CATALOG",
    "instruments": [
      {
        "displayName": "GOES-P: EXIS 1.0-8.0"
      }
    ],
    "beginTime": "2025-08-12T00:42Z",
    "peakTime": "2025-08-12T00:59Z",
    "endTime": "2025-08-12T01:18Z",
    "classType": "M1.5",
    "sourceLocation": "N05W94",
    "activeRegionNum": 14168,
    "note": "",
    "submissionTime": "2025-08-12T01:24Z",
    "versionId": 1,
    "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/FLR/40548/-1",
    "linkedEvents": None,
    "sentNotifications": None
  },
  {
    "flrID": "2025-08-12T01:18:00-FLR-001",
    "catalog": "M2M_CATALOG",
    "instruments": [
      {
        "displayName": "GOES-P: EXIS 1.0-8.0"
      }
    ],
    "beginTime": "2025-08-12T01:18Z",
    "peakTime": "2025-08-12T01:23Z",
    "endTime": "2025-08-12T01:27Z",
    "classType": "M1.8",
    "sourceLocation": "N05W94",
    "activeRegionNum": 14168,
    "note": "",
    "submissionTime": "2025-08-12T01:53Z",
    "versionId": 1,
    "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/FLR/40551/-1",
    "linkedEvents": [
      {
        "activityID": "2025-08-12T01:45:00-CME-001"
      }
    ],
    "sentNotifications": None
  },
  {
    "flrID": "2025-08-12T12:03:00-FLR-001",
    "catalog": "M2M_CATALOG",
    "instruments": [
      {
        "displayName": "GOES-P: EXIS 1.0-8.0"
      }
    ],
    "beginTime": "2025-08-12T12:03Z",
    "peakTime": "2025-08-12T12:18Z",
    "endTime": "2025-08-12T12:39Z",
    "classType": "C6.1",
    "sourceLocation": "N05W98",
    "activeRegionNum": 14168,
    "note": "",
    "submissionTime": "2025-08-12T19:00Z",
    "versionId": 1,
    "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/FLR/40561/-1",
    "linkedEvents": [
      {
        "activityID": "2025-08-12T13:25:00-CME-001"
      }
    ],
    "sentNotifications": None
  },
  {
    "flrID": "2025-08-13T19:14:00-FLR-001",
    "catalog": "M2M_CATALOG",
    "instruments": [
      {
        "displayName": "GOES-P: EXIS 1.0-8.0"
      }
    ],
    "beginTime": "2025-08-13T19:14Z",
    "peakTime": "2025-08-13T19:39Z",
    "endTime": "2025-08-13T19:57Z",
    "classType": "C4.3",
    "sourceLocation": "S08W100",
    "activeRegionNum": 14174,
    "note": "",
    "submissionTime": "2025-08-13T21:12Z",
    "versionId": 1,
    "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/FLR/40576/-1",
    "linkedEvents": [
      {
        "activityID": "2025-08-13T20:23:00-CME-001"
      }
    ],
    "sentNotifications": None
  }
]

# %%
df = pd.json_normalize(data)
df.head(10)
# Out:
#                          flrID      catalog  \
# 0  2025-08-10T02:46:00-FLR-001  M2M_CATALOG
# 1  2025-08-10T14:57:00-FLR-001  M2M_CATALOG
# 2  2025-08-10T22:51:00-FLR-001  M2M_CATALOG
# 3  2025-08-10T23:20:00-FLR-001  M2M_CATALOG
# 4  2025-08-11T03:42:00-FLR-001  M2M_CATALOG
# 5  2025-08-11T14:20:00-FLR-001  M2M_CATALOG
# 6  2025-08-11T15:18:00-FLR-001  M2M_CATALOG
# 7  2025-08-11T22:12:00-FLR-001  M2M_CATALOG
# 8  2025-08-12T00:42:00-FLR-001  M2M_CATALOG
# 9  2025-08-12T01:18:00-FLR-001  M2M_CATALOG
#
#                                  instruments          beginTime  \
# 0  [{'displayName': 'GOES-P: EXIS 1.0-8.0'}]  2025-08-10T02:46Z
# 1  [{'displayName': 'GOES-P: EXIS 1.0-8.0'}]  2025-08-10T14:57Z
# 2  [{'displayName': 'GOES-P: EXIS 1.0-8.0'}]  2025-08-10T22:51Z
# 3  [{'displayName': 'GOES-P: EXIS 1.0-8.0'}]  2025-08-10T23:20Z
# 4  [{'displayName': 'GOES-P: EXIS 1.0-8.0'}]  2025-08-11T03:42Z
# 5  [{'displayName': 'GOES-P: EXIS 1.0-8.0'}]  2025-08-11T14:20Z
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   flrID              12 non-null     object
#  1   catalog            12 non-null     object
#  2   instruments        12 non-null     object
#  3   beginTime          12 non-null     object
#  4   peakTime           12 non-null     object
#  5   endTime            12 non-null     object
#  6   classType          12 non-null     object
#  7   sourceLocation     12 non-null     object
#  8   activeRegionNum    12 non-null     int64
#  9   note               12 non-null     object
#  10  submissionTime     12 non-null     object
#  11  versionId          12 non-null     int64
#  12  link               12 non-null     object
#  13  linkedEvents       5 non-null      object
#  14  sentNotifications  0 non-null      object
# dtypes: int64(2), object(13)
# memory usage: 1.5+ KB

# %%
df['note'] = df['note'].apply(lambda x: None if x == "" else x)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   flrID              12 non-null     object
#  1   catalog            12 non-null     object
#  2   instruments        12 non-null     object
#  3   beginTime          12 non-null     object
#  4   peakTime           12 non-null     object
#  5   endTime            12 non-null     object
#  6   classType          12 non-null     object
#  7   sourceLocation     12 non-null     object
#  8   activeRegionNum    12 non-null     int64
#  9   note               2 non-null      object
#  10  submissionTime     12 non-null     object
#  11  versionId          12 non-null     int64
#  12  link               12 non-null     object
#  13  linkedEvents       5 non-null      object
#  14  sentNotifications  0 non-null      object
# dtypes: int64(2), object(13)
# memory usage: 1.5+ KB

# %%
df[df['note'].isnull() == False]
# Out:
#                          flrID      catalog  \
# 3  2025-08-10T23:20:00-FLR-001  M2M_CATALOG
# 6  2025-08-11T15:18:00-FLR-001  M2M_CATALOG
#
#                                  instruments          beginTime  \
# 3  [{'displayName': 'GOES-P: EXIS 1.0-8.0'}]  2025-08-10T23:20Z
# 6  [{'displayName': 'GOES-P: EXIS 1.0-8.0'}]  2025-08-11T15:18Z
#
#             peakTime            endTime classType sourceLocation  \
# 3  2025-08-10T23:30Z  2025-08-10T23:38Z      M1.0         N03W80
# 6  2025-08-11T15:36Z  2025-08-11T15:51Z      M1.6         N05W90
#
#    activeRegionNum                                               note  \
# 3            14168  Brightening from a simultaneous eruption from ...
# 6            14168  Simultaneous flaring from Active Region 14173 ...
#
#       submissionTime  versionId  \
# 3  2025-08-12T16:34Z          1
# 6  2025-08-11T16:33Z          1
#
#                                                 link  \
# 3  https://webtools.ccmc.gsfc.nasa.gov/DONKI/view...
# ...

# %%
data = [
  {
    "catalog": "M2M_CATALOG",
    "activityID": "2025-08-10T09:00:00-IPS-001",
    "location": "STEREO A",
    "eventTime": "2025-08-10T09:00Z",
    "submissionTime": "2025-08-10T17:10Z",
    "versionId": 2,
    "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/IPS/40510/-1",
    "instruments": [
      {
        "displayName": "STEREO A: IMPACT"
      },
      {
        "displayName": "STEREO A: PLASTIC"
      }
    ],
    "linkedEvents": [
      {
        "activityID": "2025-08-08T07:12:00-CME-001"
      },
      {
        "activityID": "2025-08-08T19:12:00-CME-001"
      }
    ],
    "sentNotifications": None
  },
  {
    "catalog": "M2M_CATALOG",
    "activityID": "2025-08-12T16:00:00-IPS-001",
    "location": "STEREO A",
    "eventTime": "2025-08-12T16:00Z",
    "submissionTime": "2025-08-12T19:14Z",
    "versionId": 1,
    "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/IPS/40562/-1",
    "instruments": [
      {
        "displayName": "STEREO A: IMPACT"
      },
      {
        "displayName": "STEREO A: PLASTIC"
      }
    ],
    "linkedEvents": [
      {
        "activityID": "2025-08-10T15:24:00-CME-001"
      }
    ],
    "sentNotifications": None
  }
]
