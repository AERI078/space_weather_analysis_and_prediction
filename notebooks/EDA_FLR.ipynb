# %%
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from space_weather_package import collect_data, get_path

# %%
# getting json data from api and storing in file

# json_data = collect_data.collect_donki_data('FLR')
# df = collect_data.get_dataframe('FLR', data=json_data)

# %%
path = get_path.get_json_data_path('flr')

# open json file and read data
with open(path, "r") as file:
    json_data = json.load(file)

# # get dataframe from json data- also apply basic cleaning and transformations
# df = collect_data.get_dataframe(type='FLR', data=json_data)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[10], line 5
#       3 # open json file and read data
#       4 with open(path, "r") as file:
# ----> 5     json_data = json.load(file)
#       7 # # get dataframe from json data- also apply basic cleaning and transformations
#       8 # df = collect_data.get_dataframe(type='FLR', data=json_data)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
# ...

# %%
df.head()
# Out:
#                     activityID      catalog          startTime  \
# 0  2015-01-01T08:24:00-CME-001  M2M_CATALOG  2015-01-01T08:24Z
# 1  2015-01-02T14:36:00-CME-001  M2M_CATALOG  2015-01-02T14:36Z
# 2  2015-01-03T03:24:00-CME-001  M2M_CATALOG  2015-01-03T03:24Z
# 3  2015-01-06T18:24:00-CME-001  M2M_CATALOG  2015-01-06T18:24Z
# 4  2015-01-07T16:24:00-CME-001  M2M_CATALOG  2015-01-07T16:24Z
#
#                                          instruments sourceLocation  \
# 0  [{'displayName': 'SOHO: LASCO/C2'}, {'displayN...
# 1  [{'displayName': 'SOHO: LASCO/C2'}, {'displayN...         S07W40
# 2  [{'displayName': 'SOHO: LASCO/C2'}, {'displayN...
# 3  [{'displayName': 'SOHO: LASCO/C2'}, {'displayN...
# 4  [{'displayName': 'SOHO: LASCO/C2'}, {'displayN...
#
#    activeRegionNum                                             note_x  \
# 0              NaN  Eruption visible in SDO 193, starting ~ 2014-1...
# 1              NaN  Associated with a very gradual eruption in a s...
# 2              NaN
# ...

# %%
df.shape
# Out:
# (2539, 15)

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.info()
#
# NameError: name 'df' is not defined
