# %%
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from etl_package import collect_data

# %%
json_data = collect_data.collect_donki_data('FLR')
df = collect_data.get_dataframe('FLR', data=json_data)

# %%
df.head()
# Out:
#                          flrID      catalog  \
# 0  2015-01-03T09:43:00-FLR-001  M2M_CATALOG
# 1  2015-01-04T15:18:00-FLR-001  M2M_CATALOG
# 2  2015-01-13T04:13:00-FLR-001  M2M_CATALOG
# 3  2015-01-13T04:45:00-FLR-001  M2M_CATALOG
# 4  2015-01-14T12:48:00-FLR-001  M2M_CATALOG
#
#                                     instruments          beginTime  \
# 0  [{'displayName': 'GOES15: SEM/XRS 1.0-8.0'}]  2015-01-03T09:43Z
# 1  [{'displayName': 'GOES15: SEM/XRS 1.0-8.0'}]  2015-01-04T15:18Z
# 2  [{'displayName': 'GOES15: SEM/XRS 1.0-8.0'}]  2015-01-13T04:13Z
# 3  [{'displayName': 'GOES15: SEM/XRS 1.0-8.0'}]  2015-01-13T04:45Z
# 4  [{'displayName': 'GOES15: SEM/XRS 1.0-8.0'}]  2015-01-14T12:48Z
#
#             peakTime            endTime classType sourceLocation  \
# 0  2015-01-03T09:47Z  2015-01-03T09:50Z      M1.1         S05E15
# 1  2015-01-04T15:36Z  2015-01-04T15:53Z      M1.3         S05E01
# 2  2015-01-13T04:24Z  2015-01-13T04:38Z      M5.6         N07W69
# 3  2015-01-13T04:58Z  2015-01-13T05:10Z      M4.9         N07W71
# 4  2015-01-14T12:57Z  2015-01-14T13:08Z      M2.2         N07W90
#
#    activeRegionNum                                               note  \
# 0          12253.0  Flare can be seen most prominently in SDO AIA ...
# 1          12253.0                                               None
# 2          12257.0                                               None
# 3          12257.0                                               None
# 4          12257.0                                               None
#
#       submissionTime  versionId  \
# 0  2015-01-04T02:19Z          2
# 1  2015-01-04T17:00Z          1
# 2  2015-01-13T20:13Z          3
# 3  2015-01-13T20:12Z          2
# 4  2015-01-21T16:44Z          2
#
#                                                 link  \
# 0  https://webtools.ccmc.gsfc.nasa.gov/DONKI/view...
# 1  https://webtools.ccmc.gsfc.nasa.gov/DONKI/view...
# 2  https://webtools.ccmc.gsfc.nasa.gov/DONKI/view...
# 3  https://webtools.ccmc.gsfc.nasa.gov/DONKI/view...
# 4  https://webtools.ccmc.gsfc.nasa.gov/DONKI/view...
#
#                                       linkedEvents  \
# 0                                             None
# 1                                             None
# 2  [{'activityID': '2015-01-13T05:24:00-CME-001'}]
# 3                                             None
# 4                                             None
#
#                                    sentNotifications
# 0                                               None
# 1                                               None
# 2  [{'messageID': '20150113-AL-001', 'messageIssu...
# 3                                               None
# 4                                               None

# %%
df.shape
# Out:
# (2539, 15)
